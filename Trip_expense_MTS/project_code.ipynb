# %%
## Inputs we need from the user
# Total Food ordered during the trip
# Total vehicle charges during the trip
# total stay expense during the trip
# Total numbers of people gone for the trip

Vehicle_Rent = int(input(" Enter your buses/taxi rent = "))
Food_Expense = int (input("Enter your Total amount of Food expense during the trip = "))
Hotels_Expense = int (input("Enter your Hotels Rent during the trip"))
Persons = int(input("Enter the count of Total number of people gone for the trip"))

output = (Vehicle_Rent + Food_Expense + Hotels_Expense) // Persons

print ("Each Person will pay: ",output)
# Out:
# Each Person will pay:  3125
