# %%
import pandas as pd
companies = [
    'Apple','Samsung','Adobe','cap','Microsoft','Dell Technologies','Meta','Facebook','IBM','HP'

]

values = pd.Series([1, 22, 33, 44, 55, 66, 77, 88, 99, 100],
               index = companies, name = " Top Technology companies")
values

values.loc[[
    True,  # Apple
    False, # Samsung
    True,  # Faxconn
    False, # Microsoft
    True,  # Huwai
    False, # Dell
    True,  # Meta
    True,  # sony
    False,
    False
]]

# select only japanese companies

# japanese_boolean_array
japanese_boolean_array = [False,False,False,False,False,True, False, True,False,False]

# creating a variable to store japanese_companies only
japanese_companies = values.loc[japanese_boolean_array]

japanese_companies
# Out:
# Dell Technologies    66
# Facebook             88
# Name:  Top Technology companies, dtype: int64

# %%
# Conditional Selection

# %%
values
# Out:
# Apple                  1
# Samsung               22
# Adobe                 33
# cap                   44
# Microsoft             55
# Dell Technologies     66
# Meta                  77
# Facebook              88
# IBM                   99
# HP                   100
# Name:  Top Technology companies, dtype: int64

# %%
values > 20
# Out:
# Apple                False
# Samsung               True
# Adobe                 True
# cap                   True
# Microsoft             True
# Dell Technologies     True
# Meta                  True
# Facebook              True
# IBM                   True
# HP                    True
# Name:  Top Technology companies, dtype: bool

# %%
values.loc[values > 10]
# Out:
# Samsung               22
# Adobe                 33
# cap                   44
# Microsoft             55
# Dell Technologies     66
# Meta                  77
# Facebook              88
# IBM                   99
# HP                   100
# Name:  Top Technology companies, dtype: int64

# %%
values.loc [values < 30]
# Out:
# Apple       1
# Samsung    22
# Name:  Top Technology companies, dtype: int64

# %%
# use a variable to store all the companies which have revenue less then 90000
less_9m_rev = values.loc[values < 50]
less_9m_rev
# Out:
# Apple       1
# Samsung    22
# Adobe      33
# cap        44
# Name:  Top Technology companies, dtype: int64
